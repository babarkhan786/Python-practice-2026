# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# model
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# import the data in feature matrix
X = df[['age', 'fare']]
X.age.fillna(value = X['age'].mean(), inplace = True) # Replace missing scaled values with the median

# scaled data (-3 to +3)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

## perform clustring
model = KMeans(n_clusters=5)
model.fit(X_scaled)

# assign cluster labels to data
df['cluster'] = model.labels_
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14028\2746978636.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X.age.fillna(value = X['age'].mean(), inplace = True) # Replace missing scaled values with the median
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14028\2746978636.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import joblib
joblib.dump(model, 'tips_model.joblib')
# Out:
# ['tips_model.joblib']

# %%
import seaborn as sns
df_1 = sns.load_dataset('tips')
df_1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df_1.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(df_1['smoker'])
df_1['smoker'] = le.transform(df_1['smoker'])

# %%
le = LabelEncoder()
le.fit(df_1['day'])
df_1['day'] = le.transform(df_1['day'])

# %%
df_1
# Out:
#      total_bill   tip     sex  smoker  day    time  size
# 0         16.99  1.01  Female       0    2  Dinner     2
# 1         10.34  1.66    Male       0    2  Dinner     3
# 2         21.01  3.50    Male       0    2  Dinner     3
# 3         23.68  3.31    Male       0    2  Dinner     2
# 4         24.59  3.61  Female       0    2  Dinner     4
# ..          ...   ...     ...     ...  ...     ...   ...
# 239       29.03  5.92    Male       0    1  Dinner     3
# 240       27.18  2.00  Female       1    1  Dinner     2
# 241       22.67  2.00    Male       1    1  Dinner     2
# 242       17.82  1.75    Male       0    1  Dinner     2
# 243       18.78  3.00  Female       0    3  Dinner     2
#
# [244 rows x 7 columns]

# %%
X.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %%
le = LabelEncoder()
le.fit(df_1['time'])
df_1['time'] = le.transform(df_1['time'])

# %%
df_1
# Out:
#      total_bill   tip     sex  smoker  day  time  size
# 0         16.99  1.01  Female       0    2     0     2
# 1         10.34  1.66    Male       0    2     0     3
# 2         21.01  3.50    Male       0    2     0     3
# 3         23.68  3.31    Male       0    2     0     2
# 4         24.59  3.61  Female       0    2     0     4
# ..          ...   ...     ...     ...  ...   ...   ...
# 239       29.03  5.92    Male       0    1     0     3
# 240       27.18  2.00  Female       1    1     0     2
# 241       22.67  2.00    Male       1    1     0     2
# 242       17.82  1.75    Male       0    1     0     2
# 243       18.78  3.00  Female       0    3     0     2
#
# [244 rows x 7 columns]

# %%
df_1.head()
# Out:
#    total_bill   tip     sex  smoker  day  time  size
# 0       16.99  1.01  Female       0    2     0     2
# 1       10.34  1.66    Male       0    2     0     3
# 2       21.01  3.50    Male       0    2     0     3
# 3       23.68  3.31    Male       0    2     0     2
# 4       24.59  3.61  Female       0    2     0     4

# %%
X = df_1.drop(columns=['sex'])
y=df_1['sex']

# %%
X.head()
# Out:
#    total_bill   tip  smoker  day  time  size
# 0       16.99  1.01       0    2     0     2
# 1       10.34  1.66       0    2     0     3
# 2       21.01  3.50       0    2     0     3
# 3       23.68  3.31       0    2     0     2
# 4       24.59  3.61       0    2     0     4

# %%
y.head()
# Out:
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# Name: sex, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
joblib.dump(model, 'DecisionTreeClassifier.joblib')

# %% [markdown]
# ## Load Model

# %%
model_1 = joblib.load('tips_model.joblib')

# %%
import pickle

# save the model in pickle format
with open('tips_model.pkl', 'wb') as f: # wb means write binary
    pickle.dump(model, f)

# %% [markdown]
# ## Load pickle

# %%
with open('tips_model.pkl', 'rb') as f: # rb means read binary
    loaded_model = pickle.load(f)
