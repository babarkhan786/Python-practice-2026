# %% [markdown]
# # how to import data in python using pandas
# written by: Dr. Allah Ditta Babar\
# date: 07/08/2026\
# Email: adbabar.nibge@gmail.com

# %%
#Step 1. import the libraries
import pandas as pd

# %%
#Step 2. import data
df = pd.read_excel("pandas_01_day6.xlsx")
df
#assignme write the path if you want to load data from differnt folders
# Out:
#    Height Weight Favourite Dish
# 0     5.8    101  Chicken Pulao
# 1     6.2     92        Biryani
# 2     5.9     62  Karahi Ghosht
# 3     5.9     95  Chicken Pulao
# 4     5.9     55  Chicken Pulao
# ..    ...    ...            ...
# 82    5.4     55          Pasta
# 83    5.9   75KG  Karahi Ghosht
# 84    5.4     61        Biryani
# 85    6.2     68  Chicken Pulao
# 86    5.1     96        Biryani
#
# [87 rows x 3 columns]

# %%
df.head()
# Out:
#   Height Weight Favourite Dish
# 0    5.8    101  Chicken Pulao
# 1    6.2     92        Biryani
# 2    5.9     62  Karahi Ghosht
# 3    5.9     95  Chicken Pulao
# 4    5.9     55  Chicken Pulao

# %%
df.tail()
# Out:
#    Height Weight Favourite Dish
# 82    5.4     55          Pasta
# 83    5.9   75KG  Karahi Ghosht
# 84    5.4     61        Biryani
# 85    6.2     68  Chicken Pulao
# 86    5.1     96        Biryani

# %%
df.shape
# Out:
# (87, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Height          87 non-null     object
#  1   Weight          87 non-null     object
#  2   Favourite Dish  87 non-null     object
# dtypes: object(3)
# memory usage: 2.2+ KB
