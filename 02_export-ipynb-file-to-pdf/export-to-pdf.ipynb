# %%
{
    "version": "2.0.0",
    "tasks": [
        {
            "label": "Export Notebook to HTML",
            "type": "shell",
            "command": "python",
            "args": [
                "-m",
                "jupyter",
                "nbconvert",
                "--to",
                "html",
                "${file}"
            ],
            "group": {
                "kind": "build",
                "isDefault": true
            },
            "problemMatcher": []
        }
    ]
}

# %% [markdown]
# create a .vscode folder in your working directory, save the above code as .jason

# %% [markdown]
# .vscode/tasks.json

# %% [markdown]
# Ctrl + Shift + B
